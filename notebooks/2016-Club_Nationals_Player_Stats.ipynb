# %%
import usau.reports
import usau.fantasy
import usau.markdown

# %%
from IPython.display import display, HTML
import pandas as pd
pd.options.display.width = 200
pd.options.display.max_colwidth = 200
pd.options.display.max_columns = 200

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data from csv files
usau.reports.club_nats_men_2016.load_from_csvs()
usau.reports.club_nats_mixed_2016.load_from_csvs()
usau.reports.club_nats_women_2016.load_from_csvs()
None  # No output

# %%
mens = usau.reports.club_nats_men_2016.rosters
mixed = usau.reports.club_nats_mixed_2016.rosters
womens = usau.reports.club_nats_women_2016.rosters

def compute_plus_minus(df, g_weight=1, a_weight=1, d_weight=1, turn_weight=-1):
  return g_weight * df["Goals"] + a_weight * df["Assists"] + d_weight * df["Ds"] + turn_weight * df["Turns"]
mens["+/-"] = compute_plus_minus(mens)
mixed["+/-"] = compute_plus_minus(mixed)
womens["+/-"] = compute_plus_minus(womens)

# %%
mens_res = mens.sort_values("+/-", ascending=False).reset_index(drop=True).head(50) \
    [["No.", "Name", "Team", "Goals", "Assists", "Ds", "Turns", "+/-"]] \
    .style \
    .bar(subset=['Fantasy Score', 'Goals', 'Ds', '+/-'],
         color='rgba(80, 200, 100, 0.5)') \
    .bar(subset=['Assists', 'Turns'],
         color='rgba(200, 80, 80, 0.5)')
mens_res
# Out:
#         <style  type="text/css" >
#
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row0_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 100.0%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 29.0322580645%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row0_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row0_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row0_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 100.0%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row1_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 36.8421052632%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 80.6451612903%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row1_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 33.3333333333%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row1_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 28.125%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row1_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 90.0%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row2_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 73.6842105263%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 35.4838709677%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row2_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 33.3333333333%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row2_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 21.875%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row2_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 65.0%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row3_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 78.9473684211%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 19.3548387097%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row3_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 66.6666666667%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row3_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 28.125%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row3_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 50.0%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row4_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 94.7368421053%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 6.45161290323%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row4_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 33.3333333333%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row4_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 15.625%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row4_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 50.0%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row5_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_c956d6f8_8b47_11e6_ada3_f45214435470row5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 80.6451612903%, transparent 0%);
#
#             }

# %%
mixed_res = mixed.sort_values("+/-", ascending=False).reset_index(drop=True).head(50) \
    [["No.", "Name", "Team", "Goals", "Assists", "Ds", "Turns", "+/-"]] \
    .style \
    .bar(subset=['Fantasy Score', 'Goals', 'Ds', '+/-'],
         color='rgba(80, 200, 100, 0.5)') \
    .bar(subset=['Assists', 'Turns'],
         color='rgba(200, 80, 80, 0.5)')
mixed_res
# Out:
#         <style  type="text/css" >
#
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row0_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 89.4736842105%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 40.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row0_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 25.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row0_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 22.2222222222%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row0_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 100.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row1_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 94.7368421053%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 40.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row1_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 50.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row1_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 40.7407407407%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row1_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 94.4444444444%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row2_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 47.3684210526%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 28.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row2_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 50.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row2_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 14.8148148148%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row2_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 66.6666666667%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row3_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 36.8421052632%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 28.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row3_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 100.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row3_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 33.3333333333%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row3_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 61.1111111111%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row4_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 40.0%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row4_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 41.6666666667%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row4_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 18.5185185185%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row4_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 55.5555555556%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row5_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 36.8421052632%, transparent 0%);
#
#             }
#
#             #T_c970cebe_8b47_11e6_ada3_f45214435470row5_col4 {

# %%
womens_res = womens.sort_values("+/-", ascending=False).reset_index(drop=True).head(50) \
    [["No.", "Name", "Team", "Goals", "Assists", "Ds", "Turns", "+/-"]] \
    .style \
    .bar(subset=['Fantasy Score', 'Goals', 'Ds', '+/-'],
         color='rgba(80, 200, 100, 0.5)') \
    .bar(subset=['Assists', 'Turns'],
         color='rgba(200, 80, 80, 0.5)')
womens_res
# Out:
#         <style  type="text/css" >
#
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row0_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 100.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 12.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row0_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 78.9473684211%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row0_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 33.3333333333%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row0_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 100.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row1_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 24.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 68.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row1_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 42.1052631579%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row1_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 40.7407407407%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row1_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 51.724137931%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row2_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 44.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 28.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row2_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 47.3684210526%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row2_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 29.6296296296%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row2_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 48.275862069%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row3_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 92.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 36.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row3_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 36.8421052632%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row3_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 77.7777777778%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row3_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 44.8275862069%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row4_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 52.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 20.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row4_col5 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 36.8421052632%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row4_col6 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(200, 80, 80, 0.5) 25.9259259259%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row4_col7 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 44.8275862069%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row5_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,rgba(80, 200, 100, 0.5) 48.0%, transparent 0%);
#
#             }
#
#             #T_c9871728_8b47_11e6_ada3_f45214435470row5_col4 {

# %%
print usau.markdown.pandas_to_markdown(mens_res.data.head(30))
print usau.markdown.pandas_to_markdown(mixed_res.data.head(30))
print usau.markdown.pandas_to_markdown(womens_res.data.head(30))
# Out:
# | No. |       Name       |      Team       | Goals | Assists | Ds | Turns | +/- |
# | :-- | :--------------- | :-------------- | :---- | :------ | :- | :---- | :-- |
# | 42  | Ben Lohre        | Johnny Bravo    | 21    | 9       | 0  | 0     | 30  |
# | 3   | Kurt Gibson      | Ironside        | 9     | 25      | 3  | 9     | 28  |
# | 2   | Jay Froude       | Prairie Fire    | 16    | 11      | 3  | 7     | 23  |
# | 5   | Dillon Larberg   | H.I.P           | 17    | 6       | 6  | 9     | 20  |
# | 16  | Jeffrey Babbitt  | Dig             | 20    | 2       | 3  | 5     | 20  |
# | 23  | Jimmy Mickle     | Johnny Bravo    | 8     | 25      | 6  | 20    | 19  |
# | 6   | Andre Gailits    | Furious George  | 7     | 12      | 6  | 7     | 18  |
# | 31  | Kai Marshall     | H.I.P           | 5     | 7       | 6  | 2     | 16  |
# | 4   | Joel Schlachet   | Revolver        | 14    | 5       | 0  | 3     | 16  |
# | 28  | Jack Williams    | Ring of Fire    | 12    | 5       | 2  | 4     | 15  |
# | 34  | Jesse Buchsbaum  | Chicago Machine | 12    | 9       | 1  | 7     | 15  |
# | 27  | Jake Rainwater   | Patrol          | 14    | 3       | 3  | 5     | 15  |
# | 21  | Jeff Graham      | Ironside        | 13    | 4       | 0  | 3     | 14  |
# | 24  | Joe Sefton       | Sockeye         | 10    | 7       | 1  | 4     | 14  |
# | 13  | Dalton Smith     | H.I.P           | 12    | 10      | 3  | 11    | 14  |
# | 16  | Kevin Coulter    | HIGH FIVE       | 7     | 3       | 4  | 0     | 14  |
# | 24  | Rory Orloff      | Doublewide      | 10    | 1       | 3  | 1     | 13  |
# | 1   | Simon Higgins    | Revolver        | 9     | 5       | 0  | 1     | 13  |
# | 1   | Joshua Markette  | Ironside        | 5     | 10      | 1  | 3     | 13  |
# | 13  | Alex Evangelides | Chicago Machine | 5     | 4       | 4  | 0     | 13  |
# | 14  | John Stubbs      | Ironside        | 12    | 4       | 0  | 3     | 13  |
# | 2   | Matthew Bennett  | H.I.P           | 4     | 31      | 9  | 32    | 12  |
# | 9   | Jones Clemons    | Prairie Fire    | 3     | 18      | 2  | 11    | 12  |
# | 25  | Ross Barker      | Madison Club    | 13    | 0       | 1  | 2     | 12  |
# | 19  | Ethan Pollack    | Doublewide      | 9     | 2       | 3  | 2     | 12  |
# | 3   | Jon Cox          | PoNY            | 11    | 2       | 1  | 2     | 12  |
# | 32  | Colin Camp       | Madison Club    | 9     | 6       | 0  | 4     | 11  |
# | 55  | Pawel Janas      | Chicago Machine | 6     | 8       | 1  | 4     | 11  |
# | 17  | Zane Rankin      | Sockeye         | 7     | 8       | 2  | 6     | 11  |
# | 28  | Nathan White     | Revolver        | 3     | 5       | 4  | 1     | 11  |
#
# | No. |         Name         |      Team       | Goals | Assists | Ds | Turns | +/- |
# | :-- | :------------------- | :-------------- | :---- | :------ | :- | :---- | :-- |
# | 33  | Graham Brayshaw      | No Touching!    | 18    | 10      | 5  | 7     | 26  |
# | 21  | Andrew Allen         | Ambiguous Grey  | 19    | 10      | 8  | 12    | 25  |
# | 4   | John Howell          | Public Enemy    | 10    | 7       | 8  | 5     | 20  |
# | 11  | Barrs Lang           | Blackbird       | 8     | 7       | 14 | 10    | 19  |
# | 1   | Joshua Layton        | G-Unit          | 7     | 10      | 7  | 6     | 18  |
# | 11  | Ben Katz             | Slow White      | 8     | 5       | 8  | 3     | 18  |
# | 34  | Evan Boucher         | Mischief        | 9     | 15      | 2  | 9     | 17  |
# | 42  | Samantha Valesano    | No Touching!    | 20    | 9       | 7  | 19    | 17  |
# | 5   | Eric Alexander       | NOISE           | 18    | 4       | 3  | 9     | 16  |
# | 25  | Nicholas Snuszka     | shame.          | 10    | 6       | 4  | 5     | 15  |
# | 6   | Chris Mazur          | Metro North     | 6     | 20      | 6  | 17    | 15  |
# | 16  | Brian Schoenrock     | Drag'n Thrust   | 6     | 5       | 5  | 2     | 14  |
# | 20  | Jimmy James Mcdonald | No Touching!    | 8     | 1       | 8  | 3     | 14  |
# | 55  | Todd Herman          | Slow White      | 14    | 1       | 3  | 4     | 14  |
# | 14  | Jade McLaughlin      | shame.          | 10    | 7       | 5  | 8     | 14  |
# | 24  | Alexander Thomas     | Alloy           | 11    | 0       | 5  | 2     | 14  |
# | 6   | Chris Pleshek        | Public Enemy    | 9     | 5       | 10 | 10    | 14  |
# | 9   | Jennifer Cogburn     | Seattle Mixtape | 7     | 0       | 10 | 3     | 14  |
# | 18  | Jed Farber           | Alloy           | 11    | 25      | 5  | 28    | 13  |
# | 22  | Evan Klein           | Seattle Mixtape | 5     | 9       | 9  | 10    | 13  |
# | 59  | Bryan Bernard        | Alloy           | 8     | 6       | 7  | 9     | 12  |
# | 35  | Sarah Anciaux        | Drag'n Thrust   | 7     | 3       | 8  | 6     | 12  |
# | 2   | Nancy Haskell        | Steamboat       | 15    | 3       | 4  | 10    | 12  |
# | 5   | Luke Ryan            | AMP             | 10    | 1       | 3  | 2     | 12  |
# | 77  | Daniel Khoe          | Steamboat       | 1     | 9       | 7  | 5     | 12  |
# | 99  | Timothy Gilligan     | Blackbird       | 8     | 7       | 6  | 10    | 11  |
# | 11  | Jacob Dummeldinger   | G-Unit          | 9     | 4       | 3  | 5     | 11  |
# | 3   | Nick Purifico        | AMP             | 7     | 4       | 4  | 4     | 11  |
# | 13  | Dan Patisteas        | Slow White      | 4     | 4       | 4  | 1     | 11  |
# | 12  | Christopher Waite    | Slow White      | 3     | 11      | 4  | 7     | 11  |
#
# | No. |        Name        |      Team      | Goals | Assists | Ds | Turns | +/- |
# | :-- | :----------------- | :------------- | :---- | :------ | :- | :---- | :-- |
# | 37  | Sandra Jorgensen   | Scandal        | 27    | 3       | 16 | 9     | 37  |
# | 3   | Liza Minor         | Heist          | 8     | 17      | 9  | 11    | 23  |
# | 6   | QING (Jenny) WEI   | Phoenix        | 13    | 7       | 10 | 8     | 22  |
# | 20  | Sophia Knowles     | Rival          | 25    | 9       | 8  | 21    | 21  |
# | 7   | Kami Groom         | Brute Squad    | 15    | 5       | 8  | 7     | 21  |
# | 20  | Danielle Walsh     | Green Means Go | 14    | 7       | 7  | 10    | 18  |
# | 44  | Mira Walker        | Ozone          | 9     | 13      | 5  | 9     | 18  |
# | 31  | Sara Scott         | Rival          | 10    | 19      | 8  | 19    | 18  |
# | 16  | Sarah Levinn       | Showdown       | 16    | 4       | 1  | 4     | 17  |
# | 6   | Sarah Griffith     | Seattle Riot   | 7     | 4       | 8  | 3     | 16  |
# | 20  | Briana Cahn        | Nightlock      | 12    | 4       | 5  | 6     | 15  |
# | 10  | Ashlee Davison     | Traffic        | 5     | 2       | 20 | 12    | 15  |
# | 15  | Sydney Overman     | Showdown       | 13    | 6       | 2  | 6     | 15  |
# | 2   | Emily Lloyd        | Ozone          | 11    | 4       | 4  | 4     | 15  |
# | 51  | Claire Desmond     | Fury           | 7     | 7       | 4  | 3     | 15  |
# | 11  | Melissa Gibbs      | Heist          | 7     | 4       | 5  | 2     | 14  |
# | 24  | KATELYN Travaglini | Phoenix        | 10    | 25      | 6  | 27    | 14  |
# | 25  | Shira Klane        | Brute Squad    | 2     | 7       | 8  | 3     | 14  |
# | 22  | Julia Schmaltz     | Showdown       | 6     | 4       | 6  | 4     | 12  |
# | 19  | Adrienne Lemberger | Nightlock      | 5     | 5       | 5  | 4     | 11  |
# | 7   | Austin Prucha      | Heist          | 11    | 3       | 2  | 5     | 11  |
# | 23  | Sarah Lord         | Scandal        | 5     | 15      | 2  | 12    | 10  |
# | 41  | Sophie Dagenais    | Iris           | 14    | 0       | 5  | 9     | 10  |
# | 19  | Genevieve Dufresne | Iris           | 9     | 6       | 2  | 7     | 10  |
# | 90  | Catherine Hui      | Traffic        | 9     | 9       | 8  | 16    | 10  |
# | 71  | Cassandra Wong     | Brute Squad    | 10    | 2       | 4  | 6     | 10  |
# | 30  | Jodi Mccloskey     | Rival          | 7     | 2       | 7  | 7     | 9   |
# | 16  | Kathryn Ritzmann   | Green Means Go | 7     | 8       | 9  | 15    | 9   |
# | 21  | Chelsea Murphy     | Brute Squad    | 6     | 1       | 4  | 2     | 9   |
# | 9   | Marika Austin      | Fury           | 6     | 2       | 3  | 2     | 9   |
